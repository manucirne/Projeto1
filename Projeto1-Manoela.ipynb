# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## Manoela Cirne Lima de Campos
# ___

# %% [markdown]
# ## SEGURANÇA ALIMENTAR
# ## A renda tem influência na segurança alimentar?
# ## Como isso se reflete nas diferentes regiões do país?

# %% [markdown]
# ___
# ## Introdução
#
#         Essa pesquisa se propões a analisar a evolução da fome comparando diferentes regiões do Brasil e a renda de seus moradores com base nas pesquisas de domício de 2009 (PNAD 2009) e de 2013 (PNAD 2013).
#         O objetivo é perceber como a diferença nas rendas de 2009 e 2013 afeta a segurança alimentar em cada região.

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\manucirne\Documents\CD\Projeto1

# %%
#Se usar o arquivo descompactado
dadosT09 = pd.read_csv('DOM2009.csv',sep=',')
dadosT13 = pd.read_csv('DOM2013.csv',sep=',')
#Se usar o arquivo compactado como está no dropbox púbico
#pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
dadosT13 = dadosT13[dadosT13.V4614!=999999999999]
dadosT09 = dadosT09[dadosT09.V4614!=999999999999]


dadosN09 = dadosT09[(dadosT09.UF==11) | (dadosT09.UF==12) | (dadosT09.UF==13)|(dadosT09.UF==14) | (dadosT09.UF==15) | (dadosT09.UF==16)| (dadosT09.UF==17)] 
dadosNE09 = dadosT09[(dadosT09.UF==21) | (dadosT09.UF==22) | (dadosT09.UF==23)|(dadosT09.UF==24) | (dadosT09.UF==25) | (dadosT09.UF==26)| (dadosT09.UF==27)| (dadosT09.UF==28)| (dadosT09.UF==29)] 
dadosCO09 = dadosT09[(dadosT09.UF==31) | (dadosT09.UF==32) | (dadosT09.UF==33)|(dadosT09.UF==35) ] 
dadosSE09 = dadosT09[(dadosT09.UF==41) | (dadosT09.UF==42) | (dadosT09.UF==43)] 
dadosS09 = dadosT09[(dadosT09.UF==51) | (dadosT09.UF==52) | (dadosT09.UF==53)|(dadosT09.UF==50)] 

dadosN13 = dadosT13[(dadosT13.UF==11) | (dadosT13.UF==12) | (dadosT13.UF==13)|(dadosT13.UF==14) | (dadosT13.UF==15) | (dadosT13.UF==16)| (dadosT13.UF==17)] 
dadosNE13= dadosT13[(dadosT13.UF==21) | (dadosT13.UF==22) | (dadosT13.UF==23)|(dadosT13.UF==24) | (dadosT13.UF==25) | (dadosT13.UF==26)| (dadosT13.UF==27)| (dadosT13.UF==28)| (dadosT13.UF==29)] 
dadosCO13 = dadosT13[(dadosT13.UF==31) | (dadosT13.UF==32) | (dadosT13.UF==33)|(dadosT13.UF==35) ] 
dadosSE13 = dadosT13[(dadosT13.UF==41) | (dadosT13.UF==42) | (dadosT13.UF==43)] 
dadosS13 = dadosT13[(dadosT13.UF==51) | (dadosT13.UF==52) | (dadosT13.UF==53)|(dadosT13.UF==50)] 



TotalN09 = len(dadosN09)
TotalN13 = len(dadosN13)

TotalNE09 = len(dadosNE09)
TotalNE13 = len(dadosNE13)

TotalCO09 = len(dadosCO09)
TotalCO13 = len(dadosCO13)

TotalSE09 = len(dadosSE09)
TotalSE13 = len(dadosSE13)

TotalS09 = len(dadosS09)
TotalS13 = len(dadosS13)

MrendaN09 = dadosN09.V4614.mean()
MrendaNE09 = dadosNE09.V4614.mean()
MrendaCO09 = dadosCO09.V4614.mean()
MrendaSE09 = dadosSE09.V4614.mean()
MrendaS09 = dadosS09.V4614.mean()

df_data09 = {'Regiao': ['Norte', 'Nordeste','Centroeste', 'Sudeste', 'Sul'],
           'rendamedia': [MrendaN09, MrendaNE09, MrendaCO09, MrendaSE09, MrendaS09]}
dadosrenda09 = pd.DataFrame(df_data09)

MrendaN13 = dadosN13.V4614.mean()
MrendaNE13 = dadosNE13.V4614.mean()
MrendaCO13 = dadosCO13.V4614.mean()
MrendaSE13 = dadosSE13.V4614.mean()
MrendaS13 = dadosS13.V4614.mean()

df_data13 = {'Regiao': ['Norte', 'Nordeste','Centroeste', 'Sudeste', 'Sul'],
           'rendamedia': [MrendaN13, MrendaNE13, MrendaCO13, MrendaSE13, MrendaS13]}
dadosrenda13 = pd.DataFrame(df_data13)

# %%
#dados09 = pd.DataFrame({'UF':dados09T.V0102,'total de moradores':dados09T.V0105,'Renda mensal por domicílio':dados09T.V4614,'Número de componentes do domicílio':dados09T.V4620,'Rendimento mensal per capta':dados09T.V4622,'preocupação de alimentos acabarem':dados09T.V2103,'alimentos acabaram':dados09T.V2105,'falta de dinheiro para alimentação saudável':dados09T.V2107,'comeram o que tinha/sem dinheiro':dados09T.V2109})
dados09 = dadosT09.loc[:,["UF","V4614","V2103","V2105","V2107","V2109"]]
naonulos09 = dados09[pd.notnull(dados09.V2109)&pd.notnull(dados09.V2107)&pd.notnull(dados09.V2105)&pd.notnull(dados09.V2103)]
naonulos09 = naonulos09[dados09.V4614!=999999999999]
# Out:
# C:\Users\manucirne\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
dados13 = dadosT13.loc[:,["UF","V4614","V2103","V2105","V2107","V2109"]]
naonulos13 = dados13[pd.notnull(dados13.V2109)&pd.notnull(dados13.V2107)&pd.notnull(dados13.V2105)&pd.notnull(dados13.V2103)]
naonulos13 = naonulos13[dados13.V4614!=999999999999]
# Out:
# C:\Users\manucirne\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()

# %%
naonulos09.V2103 = dados09.V2103.astype('category')
naonulos09.V2103.cat.categories = (['Sim', 'Não'])
naonulos09.V2105 = dados09.V2103.astype('category')
naonulos09.V2105.cat.categories = (['Sim', 'Não'])
naonulos09.V2107 = dados09.V2103.astype('category')
naonulos09.V2107.cat.categories = (['Sim', 'Não'])
naonulos09.V2109 = dados09.V2103.astype('category')
naonulos09.V2109.cat.categories = (['Sim', 'Não'])
naonulos09.UF = dados09.UF.astype('category')
naonulos09.UF.cat.categories = (['Rondônia', 'Acre','Amazonas','Roraima','Pará','Amapá','Tocantins','Maranhão','Piaui','Ceará','Rio Grande do Norte','Paraíba','Pernamnuco','Alagoas','Sergipe','Bahia','Minas Gerais','Espirito Santo','Rio de janeiro','Sâo Paulo','Paraná','Santa Catarina','Rio Grande do Sul','Mato Grosso do Sul','Mato Grosso','Goiás','Distrito Federal'])
naonulos09.loc[(naonulos09.UF=='Rondônia') | (naonulos09.UF=='Acre') | (naonulos09.UF=='Amazonas') | (naonulos09.UF=='Roraima') | (naonulos09.UF=='Pará') | (naonulos09.UF=='Amapá') | (naonulos09.UF=='Tocantins'),'Regiao'] = 'Norte'
naonulos09.loc[(naonulos09.UF=='Maranhão') | (naonulos09.UF=='Piaui') | (naonulos09.UF=='Caerá') | (naonulos09.UF=='Rio Grande do Norte') | (naonulos09.UF=='Paraíba') | (naonulos09.UF=='Pernambuco') | (naonulos09.UF=='Alagoas') | (naonulos09.UF=='Sergipe') | (naonulos09.UF=='Bahia'),'Regiao'] = 'Nordeste'
naonulos09.loc[(naonulos09.UF=='Minas Gerais') | (naonulos09.UF=='Espirito Santo') | (naonulos09.UF=='Rio de Janeiro') | (naonulos09.UF=='São Paulo'),'Regiao'] = 'Sudeste'
naonulos09.loc[(naonulos09.UF=='Paraná') | (naonulos09.UF=='Santa Catarina') | (naonulos09.UF=='Rio Grande do Sul'),'Regiao'] = 'Sul'
naonulos09.loc[(naonulos09.UF=='Mato Grosso do Sul') | (naonulos09.UF=='Mato Grosso') | (naonulos09.UF=='Goiás') | (naonulos09.UF=='Distrito Federal'),'Regiao'] = 'Centroeste'

# %%
naonulos13.V2103 = dados13.V2103.astype('category')
naonulos13.V2103.cat.categories = (['Sim', 'Não'])
naonulos13.V2105 = dados13.V2103.astype('category')
naonulos13.V2105.cat.categories = (['Sim', 'Não'])
naonulos13.V2107 = dados13.V2103.astype('category')
naonulos13.V2107.cat.categories = (['Sim', 'Não'])
naonulos13.V2109 = dados13.V2103.astype('category')
naonulos13.V2109.cat.categories = (['Sim', 'Não'])
naonulos13.UF = dados13.UF.astype('category')
naonulos13.UF.cat.categories = (['Rondônia', 'Acre','Amazonas','Roraima','Pará','Amapá','Tocantins','Maranhão','Piaui','Ceará','Rio Grande do Norte','Paraíba','Pernamnuco','Alagoas','Sergipe','Bahia','Minas Gerais','Espirito Santo','Rio de janeiro','Sâo Paulo','Paraná','Santa Catarina','Rio Grande do Sul','Mato Grosso do Sul','Mato Grosso','Goiás','Distrito Federal'])
naonulos13.loc[(naonulos13.UF=='Rondônia') | (naonulos13.UF=='Acre') | (naonulos13.UF=='Amazonas') | (naonulos13.UF=='Roraima') | (naonulos13.UF=='Pará') | (naonulos13.UF=='Amapá') | (naonulos13.UF=='Tocantins'),'Regiao'] = 'Norte'
naonulos13.loc[(naonulos13.UF=='Maranhão') | (naonulos13.UF=='Piaui') | (naonulos13.UF=='Caerá') | (naonulos13.UF=='Rio Grande do Norte') | (naonulos13.UF=='Paraíba') | (naonulos13.UF=='Pernambuco') | (naonulos13.UF=='Alagoas') | (naonulos13.UF=='Sergipe') | (naonulos13.UF=='Bahia'),'Regiao'] = 'Nordeste'
naonulos13.loc[(naonulos13.UF=='Minas Gerais') | (naonulos13.UF=='Espirito Santo') | (naonulos13.UF=='Rio de Janeiro') | (naonulos13.UF=='São Paulo'),'Regiao'] = 'Sudeste'
naonulos13.loc[(naonulos13.UF=='Paraná') | (naonulos13.UF=='Santa Catarina') | (naonulos13.UF=='Rio Grande do Sul'),'Regiao'] = 'Sul'
naonulos13.loc[(naonulos13.UF=='Mato Grosso do Sul') | (naonulos13.UF=='Mato Grosso') | (naonulos13.UF=='Goiás') | (naonulos13.UF=='Distrito Federal'),'Regiao'] = 'Centroeste'

# %% [markdown]
# ## Novo parâmetro - Segurança alimentar
#
#    Com as perguntas feitas aos moradores sobre o acesso aos alimentos foi possível chegar a uma única variável: Segurança Alimentar. Essa variável substituirá as respostas dadas anteriormente em uma nova coluna com duas possíveis respostas: 'Sim' e 'Não'.
#    As perguntas que foram consideradas para criar o parâmetro de segurança alimentar foram as seguintes:
#
#    -Os moradores tiveram a preocupação de que os alimentos acabassem antes de poderem comprar ou receber mais comida
#
#    -Os alimentos acabaram antes que os moradores deste domicílio tivessem dinheiro para comprar mais comida
#
#    -Os moradores ficaram sem dinheiro para ter uma alimentação saudável e variada
#
#    -Os moradores deste domicílio comeram apenas alguns alimentos que ainda tinham porque o dinheiro acabou
#
#     No momento em que as respostas foram separadas em intensidade, como por exemplo 'muita', 'pouca' ou 'regular' (segurança alimentar), percebeu-se que havia apenas as respostas extremas e não as intermediárias. Ou seja, quem respondeu sim em alguma dessa perguntas respondeu sim para todas e vice-versa. Por esse motivo só existem duas opções em segurança alimentar: 'Sim' (tem segurança alimentar) e 'Não' (não tem segurança alimentar).

# %%
dados09 = naonulos09.rename(columns={"V4614":'RMDom','V2103':'PreAliAcab','V2105':'AliAcab','V2107':'SemAliSau','V2109':'SemDComeTem'})
dados09.loc[(dados09.AliAcab == 'Sim'),'Segali'] = 'Não'
dados09.loc[(dados09.AliAcab != 'Sim') & (dados09.PreAliAcab != 'Sim') & (dados09.SemDComeTem != 'Sim') & (dados09.SemAliSau != 'Sim'),'Segali'] = 'Sim'

# %%
dados13 = naonulos13.rename(columns={"V4614":'RMDom','V2103':'PreAliAcab','V2105':'AliAcab','V2107':'SemAliSau','V2109':'SemDComeTem'})
dados13.loc[(dados13.AliAcab == 'Sim'),'Segali'] = 'Não'
dados13.loc[(dados13.AliAcab != 'Sim') & (dados13.PreAliAcab != 'Sim') & (dados13.SemDComeTem != 'Sim') & (dados13.SemAliSau != 'Sim'),'Segali'] = 'Sim'

# %% [markdown]
# ## Separação por região
#     No próximo passo, foram criadas novas tabelas. Uma para para cada região

# %%
dadosN09 = dados09[dados09.Regiao == 'Norte']
dadosNE09 = dados09[dados09.Regiao== 'Nordeste']
dadosSE09 = dados09[dados09.Regiao== 'Sudeste']
dadosS09 = dados09[dados09.Regiao== 'Sul']
dadosCO09 = dados09[dados09.Regiao== 'Centroeste']

dadosN13 = dados13[dados13.Regiao== 'Norte']
dadosNE13 = dados13[dados13.Regiao== 'Nordeste']
dadosSE13 = dados13[dados13.Regiao== 'Sudeste']
dadosS13 = dados13[dados13.Regiao== 'Sul']
dadosCO13 = dados13[dados13.Regiao== 'Centroeste']

# %% [markdown]
# ## Segurança Alimentar no Brasil

# %%
fig = plt.figure(figsize=(20, 8))
plt.subplot(121)
Segalim09 = dados09.Segali.value_counts().reindex(['Não','Sim'])
Segalim09.plot(kind='pie', colors=('blue','orange'), autopct="%.2f", legend=False,title='Segurança Alimentar 2009 - Brasil')

plt.subplot(122)
Segalim13 = dados13.Segali.value_counts().reindex(['Não','Sim'])
Segalim13.plot(kind='pie', colors=('blue','orange'), autopct="%.2f", legend=False,title='Segurança Alimentar 2013 - Brasil')

# %%
fig = plt.figure(figsize=(25, 5))
plt.subplot(151)
SegalimCO09 = dadosCO09.Segali.value_counts().reindex(['Não','Sim'])
SegalimCO09.plot(kind='pie', colors=('blue','orange'), autopct="%.2f", legend=False,title='Segurança Alimentar 2009 - Centroeste')

plt.subplot(152)
SegalimN09 = dadosN09.Segali.value_counts().reindex(['Não','Sim'])
SegalimN09.plot(kind='pie', colors=('blue','orange'), autopct="%.2f", legend=False,title='Segurança Alimentar 2009 - Norte')

plt.subplot(153)
SegalimNE09 = dadosNE09.Segali.value_counts().reindex(['Não','Sim'])
SegalimNE09.plot(kind='pie', colors=('blue','orange'), autopct="%.2f", legend=False,title='Segurança Alimentar 2009 - Nordeste')

plt.subplot(154)
SegalimSE09 = dadosSE09.Segali.value_counts().reindex(['Não','Sim'])
SegalimSE09.plot(kind='pie', colors=('blue','orange'), autopct="%.2f", legend=False,title='Segurança Alimentar 2009 - Sudeste')

plt.subplot(155)
SegalimS09 = dadosS09.Segali.value_counts().reindex(['Não','Sim'])
SegalimS09.plot(kind='pie', colors=('blue','orange'), autopct="%.2f", legend=False,title='Segurança Alimentar 2009 - Sul')

plt.tight_layout()
plt.show()

fig = plt.figure(figsize=(25, 5))
plt.subplot(151)
SegalimCO13 = dadosCO13.Segali.value_counts().reindex(['Não','Sim'])
SegalimCO13.plot(kind='pie', colors=('blue','orange'), autopct="%.2f", legend=False,title='Segurança Alimentar 2013 - Centroeste')

plt.subplot(152)
SegalimN13 = dadosN13.Segali.value_counts().reindex(['Não','Sim'])
SegalimN13.plot(kind='pie', colors=('blue','orange'), autopct="%.2f", legend=False,title='Segurança Alimentar 2013 - Norte')

plt.subplot(153)
SegalimNE13 = dadosNE13.Segali.value_counts().reindex(['Não','Sim'])
SegalimNE13.plot(kind='pie', colors=('blue','orange'), autopct="%.2f", legend=False,title='Segurança Alimentar 2013 - Nordeste')

plt.subplot(154)
SegalimSE13 = dadosSE13.Segali.value_counts().reindex(['Não','Sim'])
SegalimSE13.plot(kind='pie', colors=('blue','orange'), autopct="%.2f", legend=False,title='Segurança Alimentar 2013 - Sudeste')

plt.subplot(155)
SegalimS13 = dadosS13.Segali.value_counts().reindex(['Não','Sim'])
SegalimS13.plot(kind='pie', colors=('blue','orange'), autopct="%.2f", legend=False,title='Segurança Alimentar 2013 - Sul')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Segurança alimentar por região entre 2009 e 2013
#
#   Os gráficos a cima mostram a diferença entre a porcentagem de respostas 'Sim' e 'Não' para segurança alimentar, em cada região do país entre 2009 e 2013. É possível observar que houve uma melhora nesse parâmetro, ou seja, a segurança alimentar é maior em 2013 que em 2009.
#
#   No Centroeste essa mudança fica  mais evidente. Isso reflete que a falta de segurança alimentar nessa região é mais atrelada à renda que em outras, como o nordeste. A caatinga do nordeste impede que muitas pessoas tenham acesso a água e alimentos frescos devido ao clima árido característico. Essa questão ambiental não pode ser resolvida apenas com melhoras econômicas e distribuição de renda. A região norte tem uma questão diferente. O fato de ser menos acessível impede que os alimentos cheguem ainda frescos e em quantidade suficiente à região. Por essa característica a questão da renda também não é o único fator que pode alterar o quadro da fome, apesar de ajudar na melhora. As regiões Sudeste e Sul, sendo as mais ricas e acessíveis do país tem mudanças significativas em relação à segurança alimentar quando a renda é aumentada e distribuida.

# %%
mergedCO = pd.DataFrame({"2009": SegalimCO09, "2013": SegalimCO13})
mergedN = pd.DataFrame({"2009": SegalimN09, "2013": SegalimN13})
mergedNE = pd.DataFrame({"2009": SegalimNE09, "2013": SegalimNE13})
mergedSE = pd.DataFrame({"2009": SegalimSE09, "2013": SegalimSE13})
mergedS = pd.DataFrame({"2009": SegalimS09, "2013": SegalimS13})

# %%
listat = [1,2]
TotalN09 = len(dadosN09)
TotalN13 = len(dadosN13)
SimN09 = (len(dadosN09[dadosN09.Segali == 'Sim'])/TotalN09)*100
SimN13 = (len(dadosN13[dadosN13.Segali == 'Sim'])/TotalN13)*100
NãoN09 = (len(dadosN09[dadosN09.Segali == 'Não'])/TotalN09)*100
NãoN13 = (len(dadosN13[dadosN13.Segali == 'Não'])/TotalN13)*100

# %%
TotalN09 = len(dadosN09)
TotalN13 = len(dadosN13)

TotalNE09 = len(dadosNE09)
TotalNE13 = len(dadosNE13)

TotalCO09 = len(dadosCO09)
TotalCO13 = len(dadosCO13)

TotalSE09 = len(dadosSE09)
TotalSE13 = len(dadosSE13)

TotalS09 = len(dadosS09)
TotalS13 = len(dadosS13)

SimN09 = (len(dadosN09[dadosN09.Segali == 'Sim'])/TotalN09)*100
SimN13 = (len(dadosN13[dadosN13.Segali == 'Sim'])/TotalN13)*100
NãoN09 = (len(dadosN09[dadosN09.Segali == 'Não'])/TotalN09)*100
NãoN13 = (len(dadosN13[dadosN13.Segali == 'Não'])/TotalN13)*100

SimNE09 = (len(dadosNE09[dadosNE09.Segali == 'Sim'])/TotalNE09)*100
SimNE13 = (len(dadosNE13[dadosNE13.Segali == 'Sim'])/TotalNE13)*100

SimCO09 = (len(dadosCO09[dadosCO09.Segali == 'Sim'])/TotalCO09)*100
SimCO13 = (len(dadosCO13[dadosCO13.Segali == 'Sim'])/TotalCO13)*100

SimSE09 = (len(dadosSE09[dadosSE09.Segali == 'Sim'])/TotalSE09)*100
SimSE13 = (len(dadosSE13[dadosSE13.Segali == 'Sim'])/TotalSE13)*100

SimS09 = (len(dadosS09[dadosS09.Segali == 'Sim'])/TotalS09)*100
SimS13 = (len(dadosS13[dadosS13.Segali == 'Sim'])/TotalS13)*100

MrendaN09 = dadosN09.RMDom.mean()
MrendaNE09 = dadosNE09.RMDom.mean()
MrendaCO09 = dadosCO09.RMDom.mean()
MrendaSE09 = dadosSE09.RMDom.mean()
MrendaS09 = dadosS09.RMDom.mean()

df_data09 = {'Regiao': ['Norte', 'Nordeste','Centroeste', 'Sudeste', 'Sul'],
           'rendamedia': [MrendaN09, MrendaNE09, MrendaCO09, MrendaSE09, MrendaS09],
           'simporcentagem': [SimN09, SimNE09, SimCO09, SimSE09, SimS09]}
dadosrendasim09 = pd.DataFrame(df_data09)

MrendaN13 = dadosN13.RMDom.mean()
MrendaNE13 = dadosNE13.RMDom.mean()
MrendaCO13 = dadosCO13.RMDom.mean()
MrendaSE13 = dadosSE13.RMDom.mean()
MrendaS13 = dadosS13.RMDom.mean()

df_data13 = {'Regiao': ['Norte', 'Nordeste','Centroeste', 'Sudeste', 'Sul'],
           'rendamedia': [MrendaN13, MrendaNE13, MrendaCO13, MrendaSE13, MrendaS13],
           'simporcentagem': [SimN13, SimNE13, SimCO13, SimSE13, SimS13]}
dadosrendasim13 = pd.DataFrame(df_data13)

# %%
fig2 = plt.figure(figsize=(25, 15))

plt.subplot(231)
faixa = range(10,5000,500)
plot = dados09.RMDom.plot.hist(bins=faixa,title='Renda 09/13 - Brasil', alpha=0.7,label='2009')
plt.ylabel('Domicílios')
plt.xlabel('Renda (em reais)')
plt.legend()

faixa = range(10,5000,500)
plot2 = dados13.RMDom.plot.hist(bins=faixa,title='Renda 09/13 Brasil', alpha=0.7, ax=plot,label='2013')
plt.ylabel('Domicílios')
plt.xlabel('Renda (em reais)')
plt.legend()

# %%
fig2 = plt.figure(figsize=(25, 15))

plt.subplot(231)
faixa = range(10,5000,500)
plot = dadosN09.RMDom.plot.hist(bins=faixa,title='Renda 09/13 Norte', alpha=0.7, label='2009')
plt.ylabel('Domicílios')
plt.xlabel('Renda (em reais)')
plt.legend()

faixa = range(10,5000,500)
plot2 = dadosN13.RMDom.plot.hist(bins=faixa,title='Renda 09/13 Norte', alpha=0.7, ax=plot, label='2013')
plt.ylabel('Domicílios')
plt.xlabel('Renda (em reais)')
plt.legend()

plt.subplot(232)
plot = dadosNE09.RMDom.plot.hist(bins=faixa,title='Renda 09/13 Nordeste', alpha=0.7, label='2009')
plt.ylabel('Domicílios')
plt.xlabel('Renda (em reais)')
plt.legend()

plot2 = dadosNE13.RMDom.plot.hist(bins=faixa,title='Renda 09/13 Nordeste', alpha=0.7, ax=plot, label='2013')
plt.ylabel('Domicílios')
plt.xlabel('Renda (em reais)')
plt.legend()

plt.subplot(233)
plot = dadosCO09.RMDom.plot.hist(bins=faixa,title='Renda 09/13 Centroeste', alpha=0.7, label='2009')
plt.ylabel('Domicílios')
plt.xlabel('Renda (em reais)')
plt.legend()

plot2 = dadosCO13.RMDom.plot.hist(bins=faixa,title='Renda 09/13 Centroeste', alpha=0.7, ax=plot, label='2013')
plt.ylabel('Domicílios')
plt.xlabel('Renda (em reais)')
plt.legend()

plt.subplot(234)
plot = dadosSE09.RMDom.plot.hist(bins=faixa,title='Renda 09/13 Sudeste', alpha=0.7, label='2009')
plt.ylabel('Domicílios')
plt.xlabel('Renda (em reais)')
plt.legend()

plot2 = dadosSE13.RMDom.plot.hist(bins=faixa,title='Renda 09/13 Sudeste', alpha=0.7, ax=plot, label='2013')
plt.ylabel('Domicílios')
plt.xlabel('Renda (em reais)')
plt.legend()

plt.subplot(235)
plot = dadosS09.RMDom.plot.hist(bins=faixa,title='Renda 09/13 Sul', alpha=0.7, label='2009')
plt.ylabel('Domicílios')
plt.xlabel('Renda (em reais)')
plt.legend()

plot2 = dadosS13.RMDom.plot.hist(bins=faixa,title='Renda 09/13 Sul', alpha=0.7, ax=plot, label='2013')
plt.ylabel('Domicílios')
plt.xlabel('Renda (em reais)')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Renda por domicílio
#    A renda domiciliar entre 2009 e 2013 em cada região teve diferenças significativas. Com os gráficos é possível observar que os domicílios que têm renda entre 0 e 1000 reais diminuiu, enquanto que os domicílios que ganham entre 2000 e 4500 aumentou, em todas as regiões. Isso mostra a melhora no setor econômico do país no período em questão. Essa melhora acompanha a melhora na segurança alimentar, descrita a cima.

# %% [markdown]
# ___
# ## Conclusão

# %%
dados09 = dados09.rename(columns={"RMDom":'Renda domiciliar','PreAliAcab':'Ficou preocupado com o fim dos alimentos em casa','AliAcab':'Não comeu pois os alimentos acabaram em casa','SemAliSau':'Não tinha alimentos saudáveis em casa','SemDComeTem':'Por falta de dinheiro, comeu o que pôde encontrar', 'Segali':'Segurança alimentar'})
dados09.head()
# Out:
#          UF  Renda domiciliar  \
# 2  Rondônia             828.0
# 3  Rondônia            3160.0
# 4  Rondônia             930.0
# 6  Rondônia             465.0
# 7  Rondônia             994.0
#
#   Ficou preocupado com o fim dos alimentos em casa  \
# 2                                              Sim
# 3                                              Não
# 4                                              Não
# 6                                              Não
# 7                                              Não
#
#   Não comeu pois os alimentos acabaram em casa  \
# 2                                          Sim
# 3                                          Não
# 4                                          Não
# 6                                          Não
# 7                                          Não
#
#   Não tinha alimentos saudáveis em casa  \
# 2                                   Sim
# 3                                   Não
# 4                                   Não
# ...

# %%
dados13 = dados13.rename(columns={"RMDom":'Renda domiciliar','PreAliAcab':'Ficou preocupado com o fim dos alimentos em casa','AliAcab':'Não comeu pois os alimentos acabaram em casa','SemAliSau':'Não tinha alimentos saudáveis em casa','SemDComeTem':'Por falta de dinheiro, comeu o que pôde encontrar', 'Segali':'Segurança alimentar'})
dados13.head()
# Out:
#          UF  Renda domiciliar  \
# 2  Rondônia             350.0
# 3  Rondônia             678.0
# 4  Rondônia             800.0
# 5  Rondônia             800.0
# 6  Rondônia            1234.0
#
#   Ficou preocupado com o fim dos alimentos em casa  \
# 2                                              Não
# 3                                              Não
# 4                                              Não
# 5                                              Não
# 6                                              Não
#
#   Não comeu pois os alimentos acabaram em casa  \
# 2                                          Não
# 3                                          Não
# 4                                          Não
# 5                                          Não
# 6                                          Não
#
#   Não tinha alimentos saudáveis em casa  \
# 2                                   Não
# 3                                   Não
# 4                                   Não
# ...

# %%
fig2 = plt.figure(figsize=(20, 8))



mt = dadosrenda09.rendamedia.mean()
a = dadosrendasim09.simporcentagem.cov(dadosrenda09.rendamedia) / dadosrendasim09.simporcentagem.var()
b = dadosrenda09.rendamedia.mean() - a*dadosrendasim09.simporcentagem.mean()

plt.subplot(121)
plt.scatter(dadosrendasim09.simporcentagem, dadosrenda09.rendamedia, c='red', alpha=0.8)
plt.title('Renda média por porcentagem de segurança alimentar - 09')
plt.xlabel('% de Segurança alimentar')
plt.ylabel('Renda média em cada região')

plt.plot((dadosrendasim09.simporcentagem.min(), dadosrendasim09.simporcentagem.max()), (a*dadosrendasim09.simporcentagem.min()+b, a*dadosrendasim09.simporcentagem.max()+b), color='blue')

mt = dadosrenda13.rendamedia.mean()
a = dadosrendasim13.simporcentagem.cov(dadosrenda13.rendamedia) / dadosrendasim13.simporcentagem.var()
b = dadosrenda13.rendamedia.mean() - a*dadosrendasim13.simporcentagem.mean()

plt.subplot(122)
plt.scatter(dadosrendasim13.simporcentagem, dadosrenda13.rendamedia, c='red', alpha=0.8)
plt.title('Renda média por porcentagem de segurança alimentar - 09')
plt.xlabel('% de Segurança alimentar')
plt.ylabel('Renda média em cada região')
plt.plot((dadosrendasim13.simporcentagem.min(), dadosrendasim13.simporcentagem.max()), (a*dadosrendasim13.simporcentagem.min()+b, a*dadosrendasim13.simporcentagem.max()+b), color='blue')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Renda influenciando a segurança alimentar
#    O aumento da renda e da segurança alimentar no período selecionado mostra a relação entre esses dois parâmetros. Os gráficos acima deixam clara essa simbiose. Quanto maior a renda média da população, maior a segurança alimentar. Apesar de ser possível perceber que cada região reage com maior ou menor impacto à diferença de renda, em todas elas existe alguma mudança.
#
#    Fica claro também que outros recursos são necessários para extinguir a fome no país como acessibilidade (transportes) e recursos para contornar questões ambientais. Mesmo assim, conclui-se que melhorar o quadro econômico do país e distrubuir melhor a renda resulta em maior segurança alimentar.
